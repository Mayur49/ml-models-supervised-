# %%
#Decision Tree Regressor

import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
df = load_diabetes(as_frame=True).frame

# %%
X= df.drop("target", axis=1)
y=df["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth=7, min_samples_leaf=20)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=7, min_samples_leaf=20)

# %%
from sklearn.metrics import r2_score, mean_squared_error

y_pred_train = model.predict(X_train)
y_test_train = model.predict(X_test)


print("MSE Train :" , mean_squared_error(y_train, y_pred_train))
print("MSE Test :" , mean_squared_error(y_test, y_test_train))

print("r2_score Train :" , r2_score(y_train, y_pred_train))
print("r2_score Test :" , r2_score(y_test, y_test_train))
# Out:
# MSE Train : 2795.7093704335157
# MSE Test : 3177.664925233041
# r2_score Train : 0.5452860742356658
# r2_score Test : 0.41135906558189406

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(18,10))

plot_tree(
    model,
    feature_names=X.columns,
    filled=True,
    max_depth=3
)

plt.tight_layout()
plt.show()
